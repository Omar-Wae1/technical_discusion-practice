# %% [markdown]
# <a href="https://colab.research.google.com/github/Omar-Wae1/technical_discusion-practice/blob/main/technical_docs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### ingest

# %%
def hello():
  return "hi i am testing the collab"

hello()
# Out:
# 'hi i am testing the collab'
